# %% [markdown]
# # Speech enhancement by Wiener filtering - Voice activity detection and all pole model

# %% [markdown]
# ***Abstract***

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Review of existing techniques (How thorough ?)

# %% [markdown]
# ## Algorithm description

# %% [markdown]
# ## Results and discussion

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## Bibliography
